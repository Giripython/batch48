# %%
a=1000
b=2000
c=4000
print a
print b
print c
# Out:
# 1000
# 2000
# 4000

# %%
a=100
b=200
c=a
print a
print b
print c
# Out:
# 100
# 200
# 100

# %%
x=10
y=20
z=30
print x,id(x)
print y,id(y)
print z,id(z)
# Out:
# 10 44065232
# 20 44064992
# 30 44064752

# %%
a=1000
b=2000
c=a
print a,id(a)
print b,id(b)
print c,id(c)
# Out:
# 1000 70261368
# 2000 70271352
# 1000 70261368

# %%
x=100
y=200
z=x
x=400
print x,id(x)
print y,id(y)
print z,id(z)
# Out:
# 400 70270608
# 200 44070632
# 100 44067056

# %%
s1="python program"
s2="computer progarm"
s3=s1
s4="python program"
print s1,id(s1)
print s2,id(s2)
print s3,id(s3)
print s4,id(s4)
# Out:
# python program 80241456
# computer progarm 80129472
# python program 80241456
# python program 80242272

# %%
s="khyaathi"
print s[0]
print s[1]
print s[2]
print s[3]
print s[4]
print s[5]
print s[6]
print s[7]
# Out:
# k
# h
# y
# a
# a
# t
# h
# i

# %%
a="giri"
print a[0],id(a[0])
print a[1],id(a[1])
print a[2],id(a[2])
print a[3],id(a[3])
# Out:
# g 44786392
# i 44207000
# r 43958320
# i 44207000

# %%
a=1000
b=2000
# arithmetic operators
print a+b
print a-b
print a*b
print a/b
print a//b
print a%b
print a**b
# Out:
# 3000
# -1000
# 2000000
# 0
# 0
# 1000
# ...

# %%
a=10 
b=20
# boolean operators
print a>b
print a>=b
print a==b
print a!=b
print a<b
print a<=b

#bitwise operations
print a&b
print a|b
print a^b
# Out:
# False
# False
# False
# True
# True
# True
# 0
# 30
# 30
